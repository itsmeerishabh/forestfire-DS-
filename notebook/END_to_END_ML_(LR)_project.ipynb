# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("/content/Algerian_forest_fires_dataset_UPDATE.csv",header = 1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df1 = df.iloc[:122,:]

# %%
df1.shape
# Out:
# (122, 14)

# %%
df1.iloc[[121]]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 121  30    09  2012          25  78  14   1.4   45  1.9  7.5  0.2  2.4  0.1
#
#        Classes
# 121  not fire

# %%
df1["Region"]=0
# Out:
# <ipython-input-17-55d7892cc27d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Region"]=0

# %%
df1.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.iloc[[122]]
# Out:
#                                day month year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN  NaN         NaN  NaN  NaN   NaN
#
#     FFMC  DMC   DC  ISI  BUI  FWI Classes
# 122  NaN  NaN  NaN  NaN  NaN  NaN       NaN

# %%
df2 = df.iloc[124:,:]

# %%
df2.head()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 124  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 125  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 126  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 127  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
# 128  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8  6.5  0.9
#
#        Classes
# 124  not fire
# 125  not fire
# 126  not fire
# 127  not fire
# 128  not fire

# %%
df2["Region"]=1
# Out:
# <ipython-input-24-f4c912bcbb28>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Region"]=1

# %%
df1.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df1.shape
# Out:
# (122, 15)

# %%
df2.head()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 124  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 125  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 126  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 127  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
# 128  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8  6.5  0.9
#
#        Classes    Region
# 124  not fire          1
# 125  not fire          1
# 126  not fire          1
# 127  not fire          1
# 128  not fire          1

# %%
df2.shape
# Out:
# (122, 15)

# %%
df3 = pd.concat([df1, df2], axis=0)

# %%
df3.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 241  6.5       fire          1
# 242    0   not fire          1
# 243  0.2   not fire          1
# 244  0.7   not fire          1
# 245  0.5  not fire           1

# %%
df.shape
# Out:
# (246, 14)

# %%
df3.shape
# Out:
# (244, 15)

# %%
df3.head() #we make region in which 0 represent Bejaia Region Dataset and 1 represent Sidi-Bel Abbes Region Dataset
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 30.5+ KB

# %%
df3.columns=df3.columns.str.strip() #and str.strip and str.replace() are so usefull always remember

# %%
df3.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df3[["day","month","year","Temperature","RH","Ws"]]=df3[["day","month","year","Temperature","RH","Ws"]].astype(int)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 30.4+ KB

# %%
df3["Rain"]=df3["Rain"].astype(float)

# %%
df3["FFMC"]=df3["FFMC"].astype(float)

# %%
df3["DMC"]=df3["DMC"].astype(float)

# %%
df3["DC"]=df3["DC"].astype(float)

# %%
df3["ISI"]=df3["ISI"].astype(float)

# %%
df3["BUI"]=df3["BUI"].astype(float)

# %%
df3["FWI"]=df3["FWI"].astype(float)

# %%
df3.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 30.4+ KB

# %%
#so far we have chaange the datatypes and make the proper row and columns datawise and remove the null value

# %%
df3.dropna(inplace = True)

# %%
df3.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df3.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df3.to_csv("fire_clean_data.csv",index = False)

# %%
df3=df3.drop(["day","month","year"],axis =1)

# %%
df3.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df3["Classes"].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df3["Classes"] = df3["Classes"].str.strip()

# %%
df3["Classes"].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
df3["Classes"] = np.where(df3["Classes"].str.contains("not fire"), 0, 1)

# %%
df3["Classes"].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %%
## Percentage for Pie Chart
percentage=df3['Classes'].value_counts(normalize=True)*100

# %%
percentage
# Out:
# 1    56.378601
# 0    43.621399
# Name: Classes, dtype: float64

# %%
# plotting piechart
classlabels=["Fire","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title("Pie Chart of Classes")
plt.show()

# %%
plt.figure(figsize=(12,7))

sns.heatmap(df3.corr(),annot = True)
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 6))
 # Adjust figsize as needed
plt.subplot(341)
sns.histplot(data=df3, x=df3['Temperature'], bins=20, kde=True, color='blue')
plt.subplot(342)
sns.histplot(data=df3, x=df3['RH'], bins=20, kde=True, color='blue')
plt.subplot(343)
sns.histplot(data=df3, x=df3['Ws'], bins=20, kde=True, color='blue')
plt.subplot(344)
sns.histplot(data=df3, x=df3['Rain'], bins=20, kde=True, color='blue')
plt.subplot(345)
sns.histplot(data=df3, x=df3['FFMC'], bins=20, kde=True, color='blue')
plt.subplot(346)
sns.histplot(data=df3, x=df3['DMC'], bins=20, kde=True, color='blue')
plt.subplot(347)
sns.histplot(data=df3, x=df3['DC'], bins=20, kde=True, color='blue')
plt.subplot(348)
sns.histplot(data=df3, x=df3['ISI'], bins=20, kde=True, color='blue')
plt.subplot(349)
sns.histplot(data=df3, x=df3['BUI'], bins=20, kde=True, color='blue')
plt.subplot(341)
sns.histplot(data=df3, x=df3['FWI'], bins=20, kde=True, color='blue')
# Out:
# <Axes: xlabel='Temperature', ylabel='Count'>

# %%
df3.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
#make dependent and independent features
x =df3.drop(["FWI"],axis = 1)
y = df3["FWI"]

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 241    6.5
# 242    0.0
# 243    0.2
# 244    0.7
# 245    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)

# %%
x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
plt.figure(figsize=(12,7))
sns.heatmap(x_train.corr(),annot = True)
# Out:
# <Axes: >

# %%
#remove the feature which have highly corrlerated

# %%
len(x_train.corr())
# Out:
# 11

# %%
a = 1
for i in range(a):
  print(i)
# Out:
# 0

# %%
len(x_train.columns)
# Out:
# 11

# %%
x_train.columns[0]
# Out:
# 'Temperature'

# %%
x_train.corr().iloc[0,2]
# Out:
# -0.30597667466611456

# %%
#features selection
def correlation(dataset,threshold):
  col_corr = set()
  corr_matrix  = dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
      if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

columns = correlation(x_train,0.85)
columns
# Out:
# {'Temperature'}

# %%
#after selecting the feature drop them from the dataframe

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.transform(x_test)

# %%
#understanding with the box plot
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
plt.subplot(121)
sns.boxplot(data = x_train)
plt.title("before scaling")
plt.subplot(122)
sns.boxplot(data = x_train_scaled)
plt.title("after scaling")
# Out:
# Text(0.5, 1.0, 'after scaling')

# %%
#doing with the linear model

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

LR=LinearRegression()
LR.fit(x_train_scaled,y_train)
y_predict = LR.predict(x_test_scaled)
mae = mean_absolute_error(y_test,y_predict)
r2 = r2_score(y_test,y_predict)
print("mean_absolute_error " , mae) #MAE usiing coz lots of outliers present
print("r2 score " , r2)
# Out:
# mean_absolute_error  0.4654460800094095
# r2 score  0.9893850294922101

# %%
#doing with the Lasso
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

Laa=Lasso()
Laa.fit(x_train_scaled,y_train)
y_predict_laa = Laa.predict(x_test_scaled)
mae = mean_absolute_error(y_test,y_predict_laa)
r2 = r2_score(y_test,y_predict_laa)
print("mean_absolute_error " , mae)
print("r2 score " , r2)
# Out:
# mean_squared_error  1.0816323165898813
# r2 score  0.9548117077009715

# %%
#doing with the Ridge
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

Ri=Ridge()
Ri.fit(x_train_scaled,y_train)
y_predict_Ri = Ri.predict(x_test_scaled)
mae = mean_absolute_error(y_test,y_predict_Ri)
r2 = r2_score(y_test,y_predict_Ri)
print("mean_absolute_error " , mae)
print("r2 score " , r2)
# Out:
# mean_absolute_error  0.503285697341684
# r2 score  0.9871729594175267

# %%
#doing with the ElasticNet
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

EN=ElasticNet()
EN.fit(x_train_scaled,y_train)
y_predict_EN = EN.predict(x_test_scaled)
mae = mean_absolute_error(y_test,y_predict_EN)
r2 = r2_score(y_test,y_predict_EN)
print("mean_absolute_error " , mae)
print("r2 score " , r2)
# Out:
# mean_absolute_error  1.6830954467418584
# r2 score  0.900671789556956

# %%
#lets take the Ridge model coz it will also reduce the overfitting
import pickle
pickle.dump(sc,open("scaler_file.pkl","wb"))
pickle.dump(Ri,open("Ridge_file.pkl","wb"))
